# %% [markdown]
# WELCOME TO EXERCISE 4 that is based on the topic of Einsum and Einops as explored in Episode 4 of the Mechanistic Interpretability 101 Playlist (Check it here:[Episode 4](https://youtu.be/LTlyZWj74d4?si=8B2zRO2RmYB-yRMC)).
#
# Here are a few questions to help you practice the concepts we learned and solidify your understanding.
#
# There is no need to submit answers anywhere, if you feel stuck, do take help of online resources to imporove your understanding, the purpose of this exercise is to help you learn ✨
#
# ![Episode_04 (1).png](data:image/png;base64,...)

# %%
# Einsum and Einops Exercise imports

import torch
import numpy as np
import timeit

# %% [markdown]
# ---

# %% [markdown]
# # Question 1
#
# Use einsum to calculate the dot product of a and b.

# %%
a = torch.tensor([1, 2, 3])
b = torch.tensor([4, 5, 6])

# Your Code Here

# %% [markdown]
# ---

# %% [markdown]
# # Question 2
#
# Use einsum to compute the outer product of a and b.
# The result should be a matrix where each element is the product of an element from a and an element from b.

# %%
a = torch.tensor([1, 2])
b = torch.tensor([3, 4, 5])

# Your Code Here

# %% [markdown]
# ---

# %% [markdown]
# # Question 3
#
# Perform matrix multiplication between A and B using einsum.

# %%
A = torch.tensor([[1, 2], [3, 4]])
B = torch.tensor([[5, 6], [7, 8]])

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 4
#
# Perform batch matrix multiplication using einsum where you multiply 10 matrices from batch_a and batch_b.

# %%
batch_a = torch.randn(10, 2, 3)
batch_b = torch.randn(10, 3, 2)

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 5
#
# Rearrange the tensor x from (batch, height, width, channels) to (batch, channels, height, width) using einops.

# %%
x = torch.randn(5, 64, 64, 3)  # 5 images, 64x64 resolution, 3 channels (RGB)

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 6
#
# Use einops.rearrange to tile these 4 images side by side into one wide image of shape (64, 256).

# %%
ims = torch.randn(4, 64, 64)  # 4 grayscale images of size 64x64

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 7
#
# Use einsum to perform a transpose for each matrix in the batch, resulting in a tensor with shape (5, 4, 3).

# %%
matrices = torch.randn(5, 3, 4)  # 5 matrices, each 3x4

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 8
#
# First, use einsum to normalize each image by subtracting the mean value from each pixel.
# Then, use einops to rearrange the images into a grid of 2x4 images for visualization.

# %%
images = torch.randn(8, 64, 64, 3)  # 8 RGB images

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 9
#
# Use einsum to sum over the height and width dimensions for each image and channel, producing a tensor of shape (10, 3).

# %%
tensor = torch.randn(10, 3, 32, 32)  # 10 images, 3 channels, 32x32 pixels

# Your Code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 10
#
# Use einops.reduce to compute the average color for each image across the height and width dimensions. Your result should have the shape (10, 3)

# %%
ims = torch.randn(10, 32, 32, 3)  # 10 images, 32x32 resolution, 3 channels

# Your Code here

# %% [markdown]
# ![congrats.png](data:image/png;base64,...)
