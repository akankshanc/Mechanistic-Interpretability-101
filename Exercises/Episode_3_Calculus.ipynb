# %% [markdown]
# WELCOME TO EXERCISE 3 that is based on the topic of **Calculus** as explored in Episode 3 of the Mechanistic Interpretability 101 Playlist (Check it here: [Episode 3](https://youtu.be/Ndwh_etqx14?si=iZl1ex-J8RW7r3dq)).
#
# Here are a few questions to help you practice the concepts we learned and solidify your understanding.
#
# There is no need to submit answers anywhere, if you feel stuck, do take help of online resources to imporove your understanding, the purpose of this exercise is to help you learn ✨
#
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## Question 1
#
# Find the derivative of $$ f(x) = \left(\frac{\sin^2(x)}{x^2}\right) $$
#
# Interpret the meaning of the derivative in the context of oscillation with decaying amplitude over distance.

# %% [markdown]
# ---

# %% [markdown]
# ## Question 2
#
# Find the derivative of $$ g(x) =  \left( \ln(x^2 + 1) \cdot e^{-x} \right) $$
#
# What does the derivative tell us about the behavior of the function as
# 𝑥→∞?

# %% [markdown]
# ---

# %% [markdown]
# # Question 3
#
# Identify the critical points and determine their nature (local maxima, minima, or points of inflection) for:$$ f(x) = \left( x^3 - 6x^2 + 9x \right) $$

# %% [markdown]
# ---

# %% [markdown]
# # Question 4
#
# Find the critical points and determine their nature for:
#
# $$ g(x) = \left( x \cdot e^{-x} \right) $$
#
# Explain why this function has a maximum and no minimum by analyzing the derivative.

# %% [markdown]
# ---

# %% [markdown]
# # Question 5
#
# Calculate the second derivative for:
#
# $$ f(x) = \left( x^4 - 8x^2 + 16 \right) $$
#
# Determine the concavity at
# 𝑥 = 2 and 𝑥 = −2.
#
# What does this tell you about the shape of the graph near these points?

# %% [markdown]
# ---

# %% [markdown]
# # Question 6
#
# Find the second derivative for:
#
# $$ g(x) = \left( \sin(x) \cdot \cos(x) \right) $$
#
# Identify the points where the concavity changes (inflection points).

# %% [markdown]
# ---

# %% [markdown]
# # Question 7
#
# Compute the first and second partial derivatives for
#
# $$ f(x,y) = x^3y^2 + e^{xy} $$
#
# Find the critical points and classify them as local maxima, minima, or saddle points using the second partial derivative test.

# %% [markdown]
# ---

# %% [markdown]
# # Question 8
# Calculate
# $$ \frac{\partial g}{\partial x}, \frac{\partial g}{\partial y} , \frac{\partial g}{\partial z} $$ for:
#
# $$ g(x,y,z,) = ln(xy) + z^2 \cdot sin (x + y) $$
#
# How would changing
# 𝑧 affect the gradient in terms of 𝑥 and 𝑦.

# %% [markdown]
# ---

# %% [markdown]
# ## Question 9
#
# Differentiate 𝑘 with respect to 𝑥 and 𝑦 using the chain rule.
#
# $$ k(x,y) = e^{x^2y} \cdot \sin(y + \ln(x))$$

# %% [markdown]
# ---

# %% [markdown]
# ## Question 10
#
# The water flow rate into a tank is given by
# $$ f(t) = 10Sin(t) + 5 $$ liters per minute.
#
# Use integration to find the total volume of water that flows into the tank over one hour. Interpret the result in the context of varying flow rates.

# %% [markdown]
# ---

# %% [markdown]
# ![congrats.png](data:image/png;base64,...)
