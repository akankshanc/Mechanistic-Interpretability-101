# %% [markdown]
# WELCOME TO EXERCISE 2 that is based on the topic of *Probability, Statistics and Information Theory * as explored in Episode 2 of the Mechanistic Interpretability 101 Playlist (Check it here: [Episode 2](https://youtu.be/Ye-fqKWA37E?si=EpnHgwYmnb2SsEP1)).
#
# Here are a few questions to help you practice the concepts we learned and solidify your understanding.
#
# There is no need to submit answers anywhere, if you feel stuck, do take help of online resources to imporove your understanding, the purpose of this exercise is to help you learn ✨
#
# ![e2.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %%
# Probability, Statistics, Information Theory Assignment Imports
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ---

# %% [markdown]
# # Question 1: Plotting a Normal Distribution
#
#   Plot the probability density function (PDF) of a normal distribution with mean 0 and standard deviation 1.
#
#   Label the axes and indicate the mean on the plot.

# %%
mean = 0
std_dev = 1
x = np.linspace(-4, 4, 100)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 2: Plotting a Binomial Distribution
#
#   Plot the probability mass function (PMF) of a binomial distribution with n=10 and p=0.5.
#
#  Include a bar plot showing the probabilities of different outcomes.

# %%
n = 10
p = 0.5
x = np.arange(0, n+1)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 3: Plotting a Poisson Distribution
#
#   Plot the PMF of a Poisson distribution with lambda = 3.
#
#   Plot for values from 0 to 15. Label the axes and the title appropriately.

# %%
lambda_val = 3
x = np.arange(0, 16)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 4: Comparing Two Normal Distributions
#
#   Plot the PDFs of two normal distributions on the same graph.
#
#   One with mean 0 and std 1, and another with mean 2 and std 0.5.
#
#   Indicate the means on the plot and discuss how the distributions differ.

# %%
mean1, std1 = 0, 1
mean2, std2 = 2, 0.5
x = np.linspace(-4, 6, 100)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 5: Comparing Two Normal Distributions
#
#  Plot the PDFs of two normal distributions on the same graph.
#
#  One with mean 0 and std 1, and another with mean 2 and std 0.5.
#
#  Indicate the means on the plot and discuss how the distributions differ.

# %%
# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 6: Visualizing Entropy with a Bernoulli Distribution
#
#  Plot the entropy of a Bernoulli distribution as a function of the probability p.
#
#  Plot p values ranging from 0 to 1 and calculate the entropy at each point.

# %%
p_values = np.linspace(0.01, 0.99, 100)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 7: Plotting a Cumulative Distribution Function (CDF)
#
#  Plot the cumulative distribution function (CDF) of a standard normal distribution.
#
#  Label the axes and highlight the 95th percentile on the plot.

# %%
mean = 0
std_dev = 1
x = np.linspace(-4, 4, 100)

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 8: Simulating a Markov Chain
#
# Consider the following Morkov Chain which is very similar to the one we covered in the episode.
#
# Calculate the following:
#
# a) Weather for tomorrow
#
# b) Weather for day after tomorrow
#
# ![mc.png](data:image/png;base64,...)

# %%
n_steps = 2

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 9: Calculating the Entropy
#
#  Recollect the example from the episode explaining the concept of Entropy.
#
#  Entropy is the amount of surprise in the event, so randomly picking a yellow ball from Basket A would be having high entropy considering there are 9 blue balls in Basket A and only 1 yellow ball.
#
#  We have already calculated the total entropy of the system as well as entropy of picking a yellow ball and blue ball from basket A, repeat the same calculations for Basket B and C.
#
#  ![e2e.png](data:image/png;base64,...)

# %%
# Your code here

# %% [markdown]
# ---

# %% [markdown]
# # Question 10: Understanding KL Divergence through a Real-World Example
#  Suppose you have two probability distributions representing user behavior on a website.
#
#  Distribution P is the actual observed user behavior: [0.4, 0.3, 0.2, 0.1], corresponding to the probabilities of users visiting different sections of the website.
#
# Distribution Q is a theoretical model's prediction of user behavior: [0.3, 0.3, 0.2, 0.2].
#
#  a) Compute the KL Divergence from Q to P (i.e., KL(P || Q)).
#
#  b) Plot the distributions P and Q side by side as bar plots.
#
#  c) Interpret the result of the KL Divergence in this context. What does it tell you about the difference between the actual and predicted user behaviors?

# %%
P = np.array([0.4, 0.3, 0.2, 0.1])

Q = np.array([0.3, 0.3, 0.2, 0.2])

# Your code here

# %% [markdown]
# ---

# %% [markdown]
# ![congrats.png](data:image/png;base64,...)
